# %%
print("     MULTIPLIACION DE CEDENA DE CARACTERES     ")
a = str (input("INTRODUCE LA CADENA "))
b = int (input("NUMERO DE REPETICION"))
n = 0
while (n < b):
  n = n + 1
  print(a)
# Out:
#      MULTIPLIACION DE CEDENA DE CARACTERES
# INTRODUCE LA CADENA HOLA
# NUMERO DE REPETICION2
# HOLA
# HOLA
