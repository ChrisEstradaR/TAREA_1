# %%
print("     NUMERO FACTORIAL") 
def factorial(entero):
  i = 1
  fact = 1 
  while i < entero  :
    i = i + 1
    fact = fact * i 
    res = fact
  print(" RESULTADO  FACTORIAL  :", res)
a = int (input(" INGRESAR NUMERO ENTERO :"))
factorial(a)
# Out:
#      NUMERO FACTORIAL
#  INGRESAR NUMERO ENTERO :4
#  RESULTADO  FACTORIAL  : 24
