# %%
print(" CREADOR DE TRIANGULO ESCALENO")
def triangulo(n):
  """
  for i in range(1,n+1):
    "*" * i
    []
    "\n".join()
  """
  return "\n".join(["*"*i for i in range(1,n+1)])
a = int(input(" INGRESAR NUMERO: "))
triangulo (a)
# Out:
#  CREADOR DE TRIANGULO ESCALENO
#  INGRESAR NUMERO: 4
# '*\n**\n***\n****'
