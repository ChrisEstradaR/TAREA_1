# %%
print("         CONTROL DE PAGO ")

def pago(numh, pph):

  resc = numh * pph
  print("PAGO AL DIA :", resc)

  resd = (numh * pph)*5
  print("PAGO A LA SEMANA :",resd)

  resd = (numh * pph)*20
  print("PAGO AL MES :",resd)

a = int (input("INGRESAR NUMERO DE HORAS POR DIA :"))
b = 150

pago(a, b)
# Out:
#          CONTROL DE PAGO
# INGRESAR NUMERO DE HORAS POR DIA :2
# PAGO AL DIA : 300
# PAGO A LA SEMANA : 1500
# PAGO AL MES : 6000
